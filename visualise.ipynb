# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('D:/Python_Projects/hav_cpp_from_python_2/cmake-build-debug/output.csv')
state_x = df['state_x']
state_y = df['state_y']
gps_x = df['longitude']
gps_y = df['latitude']

# Create the plot
plt.plot(state_x, state_y, label='State')
plt.plot(gps_x, gps_y, label='GPS')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\miniconda3\envs\detector\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File d:\miniconda3\envs\detector\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File d:\miniconda3\envs\detector\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'state_x'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 df = pd.read_csv('D:/Python_Projects/hav_cpp_from_python_2/cmake-build-debug/output.csv')
# ----> 2 state_x = df['state_x']
#       3 state_y = df['state_y']
#       4 gps_x = df['longitude']
#
# File d:\miniconda3\envs\detector\lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File d:\miniconda3\envs\detector\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'state_x'

# %%
df_selected = df.iloc[25:]
# Extract the columns you need
state_x = df_selected['state_x']
state_y = df_selected['state_y']
gps_x = df_selected['latitude']
gps_y = df_selected['longitude']

# Create the plot
plt.plot(state_x, state_y, label='State')
plt.plot(gps_x, gps_y, label='GPS')
plt.legend()
plt.show()
